# %% [markdown]
# We couldn't find any models for predicting the review rating.
#
# Our Accuracy : 96%
#
# Code from internet : 79 lines
#
#
# Our Code : 134

# %%
import numpy as np
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk import tokenize
from nltk.corpus import stopwords   
from nltk import wordpunct_tokenize
from sklearn.model_selection import cross_val_predict, GridSearchCV,cross_val_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import MinMaxScaler
import math

# %% [markdown]
# #### Key Feature Engineering
# 1. ```comment (reviews)```: We extensively used this feature in our analysis. The dataset contained reviews in multiple languages such as Chinese, Spanish, and English which made it difficult for it to be analyzed. We subsetted the data to include only the reviews that were in English and performed text filtering to remove common stop words and phrases that do not significantly contribute to the meaning of the review.
#
# 2.``` price (listings, calendar)```: The price column contained data in string format with the currency symbol ‘$’ and comma separator ‘,’ attached to it. This column was manipulated to contain integer values for time-series and other analysis.
#
# 3. ```date (calendar, listings, reviews)```: The date was contained in mm-dd-yyyy format. It was transformed multiple times during the analysis to obtain weekly, monthly or yearly insights.
#
#
# 4. ```rating (listings)```: There are several ratings that hosts receive including ‘location rating’, ‘cleanliness rating’ and ‘overall rating’. Values in these columns comprised of percentages, integers, and char string. Data were standardized and transformed to a similar scale.

# %% [markdown]
# #### Dealing with Missing Values
# The data also had null values. To preserve all the information, we imputed or dropped the rows and columns containing null values while conducting exploratory analysis that made use of these features.

# %% [markdown]
# The ```comments``` feature in the ```reviews``` datasets constituted of more than 1 million values. To conduct a textual analysis on the review, it had to be split into a bag of words which would contain more than 20 million words.

# %%
listings = pd.read_csv("../data/listings.csv")

# %% [markdown]
# `host_response_time` is a categorical variable so we are replacing the text with scalar values

# %%
host_response_dict = {'within an hour': 1, 
                      'within a few hours': 2, 
                      'within a day': 3,
                     'a few days or more': 4}

listings.host_response_time = listings.host_response_time.map(host_response_dict)
listings.dropna(axis=0, how='any', subset=['host_response_time'], inplace=True)

# %%
listings.host_response_time.head()
# Out:
# 0    2.0
# 1    1.0
# 2    1.0
# 4    3.0
# 5    3.0
# Name: host_response_time, dtype: float64

# %% [markdown]
# `host_response_rate` is in string it needs to converted to float as this feature will used later for model building

# %%
listings['host_response_rate'].fillna(0, inplace=True)
listings.host_response_rate[:5]
# Out:
# 0    100%
# 1    100%
# 2    100%
# 4     93%
# 5     93%
# Name: host_response_rate, dtype: object

# %%
def per_to_numbers(price_string): 
    """converting the percentage to float 
    """
    per_to_number = float(str(price_string).split('%')[0])
    return per_to_number

# %%
listings['host_response_rate'] = listings['host_response_rate'].apply(per_to_numbers)
listings.host_response_rate.head()
# Out:
# 0    100.0
# 1    100.0
# 2    100.0
# 4     93.0
# 5     93.0
# Name: host_response_rate, dtype: float64

# %%
listings.dropna(axis=0, how='any', subset=['host_is_superhost'], inplace=True)
listings['host_is_superhost'].value_counts()
# Out:
# f    3578
# t    1339
# Name: host_is_superhost, dtype: int64

# %%
listings['host_is_superhost'].isnull().sum()
# Out:
# 0

# %%
listings.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  3781  https://www.airbnb.com/rooms/3781  20190209175027   2019-02-09
# 1  5506  https://www.airbnb.com/rooms/5506  20190209175027   2019-02-09
# 2  6695  https://www.airbnb.com/rooms/6695  20190209175027   2019-02-09
# 4  8789  https://www.airbnb.com/rooms/8789  20190209175027   2019-02-09
# 5  8792  https://www.airbnb.com/rooms/8792  20190209175027   2019-02-09
#
#                                              name  \
# 0                       HARBORSIDE-Walk to subway
# 1  **$79 Special **   Private! Minutes to center!
# 2                  $99 Special!! Home Away! Condo
# 4             Curved Glass Studio/1bd facing Park
# 5                  Large 1 Bed facing State House
#
#                                              summary  \
# 0  Fully separate apartment in a two apartment bu...
# 1  This is a private guest room with private bath...
# 2                                                NaN
# 4  Bright, 1 bed with curved glass windows facing...
# 5  Fully furnished 1bed facing the State House.  ...
#
#                                                space  \
# 0  This is a totally separate apartment located o...
# 1  **THE BEST Value in BOSTON!!*** PRIVATE GUEST ...
# 2  ** WELCOME *** FULL PRIVATE APARTMENT In a His...
# 4  Fully Furnished studio with enclosed bedroom. ...
# 5  Fully furnished, spacious one bed (king) unit ...
#
#                                          description experiences_offered  \
# 0  Fully separate apartment in a two apartment bu...                none
# 1  This is a private guest room with private bath...                none
# 2  ** WELCOME *** FULL PRIVATE APARTMENT In a His...                none
# 4  Bright, 1 bed with curved glass windows facing...                none
# 5  Fully furnished 1bed facing the State House.  ...                none
#
#                                neighborhood_overview  ... instant_bookable  \
# 0  Mostly quiet ( no loud music, no crowed sidewa...  ...                f
# 1  Peacful, Architecturally interesting, historic...  ...                t
# 2  Peaceful, Architecturally interesting, histori...  ...                t
# 4  Beacon Hill is a historic neighborhood filled ...  ...                f
# 5  Beacon Hill is a historic neighborhood filled ...  ...                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f              super_strict_30
# 1                        f  strict_14_with_grace_period
# 2                        f  strict_14_with_grace_period
# 4                        f  strict_14_with_grace_period
# 5                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                f
# 4                             f                                f
# 5                             f                                f
#
#    calculated_host_listings_count  \
# 0                               1
# 1                               6
# 2                               6
# 4                              10
# 5                              10
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            1
# 1                                            6
# 2                                            6
# 4                                           10
# 5                                           10
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            0
# 4                                            0
# 5                                            0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.32
# 1                                            0               0.66
# 2                                            0               0.73
# 4                                            0               0.40
# 5                                            0               0.21
#
# [5 rows x 106 columns]

# %%
listings['host_listings_count'].fillna(0, inplace=True)

# %% [markdown]
# Added a new column which describe the level of verification.
#
# `host_verifications` column has string data

# %%
listings['host_verification_level'] = listings.host_verifications.apply(lambda s: len(s.split(', ')))

# %%
listings['host_verification_level'].value_counts()
# Out:
# 6     1285
# 4      799
# 5      685
# 8      492
# 7      462
# 3      452
# 9      307
# 2      267
# 10      92
# 1       70
# 11       6
# Name: host_verification_level, dtype: int64

# %%
listings.dropna(axis=0, how='any', subset=['host_identity_verified'], inplace=True)
listings['host_identity_verified'].value_counts()
# Out:
# f    3245
# t    1672
# Name: host_identity_verified, dtype: int64

# %%
listings['is_location_exact'].fillna(0, inplace=True)
listings['is_location_exact'].value_counts()
# Out:
# t    4043
# f     874
# Name: is_location_exact, dtype: int64

# %% [markdown]
# There are many types of property types in our dataset we are just interested about top 10 types

# %%
propertyTypes = listings['property_type'].value_counts()[10:len(listings['property_type'].value_counts())].index.tolist()
def change_prop_type(label):
    if label in propertyTypes:
        label='Other'
    return label

# %%
listings.loc[:,'property_type']=listings.loc[:,'property_type'].apply(change_prop_type)
listings['property_type'].value_counts()
# Out:
# Apartment             3263
# House                  722
# Condominium            394
# Serviced apartment     171
# Townhouse              112
# Other                   83
# Guest suite             68
# Bed and breakfast       43
# Loft                    42
# Boutique hotel          19
# Name: property_type, dtype: int64

# %%
#checking nulls in room_type
listings['room_type'].value_counts()
listings['room_type'].isnull().sum()
# Out:
# 0

# %%
#checking nulls in bed_type
listings['bed_type'].value_counts()
listings['bed_type'].isnull().sum()
# Out:
# 0

# %%
listings.host_response_time.head()
# Out:
# 0    2.0
# 1    1.0
# 2    1.0
# 4    3.0
# 5    3.0
# Name: host_response_time, dtype: float64

# %% [markdown]
# `amenities` column is a string. We are dividing the amenities into seperate columns for the further analysis.
#
# We are assuming that *amenities* play an important role on predicting review rating

# %%
def get_amenities(column):
    am_list=[]
    for am in column:
        am=am.replace('"','')
        am=am.replace('{','')
        am=am.replace('}','')
        am_list += am.split(',')

    #am_list=am_list.remove('translation missing: en.hosting_amenity_50')    
    #am_list=am_list.remove('translation missing: en.hosting_amenity_49')
    
    am_list2=pd.DataFrame(am_list) #Transform list into a data frame

    am_list2.rename(columns={0:'amenities'},inplace=True) #replace name to categories

    am_list2=am_list2.groupby('amenities')['amenities'].count().sort_values(ascending=False) #group by category and count.
    am_list2.rename(columns={'amenities':'count'},inplace=True) #Rename column to count to then drop one level
    am_list2.reset_index(level=0)
    return am_list2

# %%
amenities=get_amenities(listings.amenities) #Total

amenities = amenities.drop(['translation missing: en.hosting_amenity_50'],axis=0)

amenities = amenities.drop(['translation missing: en.hosting_amenity_49'],axis=0)

amenities

amenities/amenities.sum()*100 #Percentage of total tags

(amenities[0:35]/amenities.sum()*100).sum()

amenities=amenities[0:10]

# %%
amenities.index
# Out:
# Index(['Wifi', 'Heating', 'Essentials', 'Smoke detector', 'Kitchen', 'Hangers',
#        'Carbon monoxide detector', 'Air conditioning', 'Shampoo',
#        'Hair dryer'],
#       dtype='object', name='amenities')

# %%
am= listings['amenities'].map(
    lambda amns: "|".join([amn.replace("}", "").replace("{", "").replace('"', "")\
                           for amn in amns.split(",")]))

##Create the list of unique amenities

#am_list=np.unique(np.concatenate(am.map(lambda amns: amns.split("|"))))[1:]

##Split amenities

am_s=am.map(lambda amns: amns.split("|"))

##Create an array with true or false for each listing

amenity_array = np.array([am_s.map(lambda amns: amn in amns) for amn in amenities.index])
amenity_array = np.transpose(amenity_array)

# %%
listings_new = pd.concat([listings, pd.DataFrame(data=amenity_array, columns=amenities.index)], axis=1)
listings_new.dropna(axis = 0 ,how='any', subset=['id'], inplace=True)
listings_new.head()
# Out:
#        id                        listing_url     scrape_id last_scraped  \
# 0  3781.0  https://www.airbnb.com/rooms/3781  2.019021e+13   2019-02-09
# 1  5506.0  https://www.airbnb.com/rooms/5506  2.019021e+13   2019-02-09
# 2  6695.0  https://www.airbnb.com/rooms/6695  2.019021e+13   2019-02-09
# 4  8789.0  https://www.airbnb.com/rooms/8789  2.019021e+13   2019-02-09
# 5  8792.0  https://www.airbnb.com/rooms/8792  2.019021e+13   2019-02-09
#
#                                              name  \
# 0                       HARBORSIDE-Walk to subway
# 1  **$79 Special **   Private! Minutes to center!
# 2                  $99 Special!! Home Away! Condo
# 4             Curved Glass Studio/1bd facing Park
# 5                  Large 1 Bed facing State House
#
#                                              summary  \
# 0  Fully separate apartment in a two apartment bu...
# 1  This is a private guest room with private bath...
# 2                                                NaN
# 4  Bright, 1 bed with curved glass windows facing...
# 5  Fully furnished 1bed facing the State House.  ...
#
#                                                space  \
# 0  This is a totally separate apartment located o...
# 1  **THE BEST Value in BOSTON!!*** PRIVATE GUEST ...
# 2  ** WELCOME *** FULL PRIVATE APARTMENT In a His...
# 4  Fully Furnished studio with enclosed bedroom. ...
# 5  Fully furnished, spacious one bed (king) unit ...
#
#                                          description experiences_offered  \
# 0  Fully separate apartment in a two apartment bu...                none
# 1  This is a private guest room with private bath...                none
# 2  ** WELCOME *** FULL PRIVATE APARTMENT In a His...                none
# 4  Bright, 1 bed with curved glass windows facing...                none
# 5  Fully furnished 1bed facing the State House.  ...                none
#
#                                neighborhood_overview  ...  Wifi Heating  \
# 0  Mostly quiet ( no loud music, no crowed sidewa...  ...  True    True
# 1  Peacful, Architecturally interesting, historic...  ...  True    True
# 2  Peaceful, Architecturally interesting, histori...  ...  True    True
# 4  Beacon Hill is a historic neighborhood filled ...  ...  True    True
# 5  Beacon Hill is a historic neighborhood filled ...  ...  True    True
#
#   Essentials Smoke detector Kitchen  Hangers  Carbon monoxide detector  \
# 0       True           True    True     True                      True
# 1       True           True   False     True                      True
# 2       True           True    True     True                      True
# 4       True           True    True     True                     False
# 5       True           True    True     True                      True
#
#   Air conditioning  Shampoo  Hair dryer
# 0             True     True        True
# 1             True     True        True
# 2             True     True        True
# 4             True    False        True
# 5             True     True       False
#
# [5 rows x 117 columns]

# %%
listings_new.dropna(axis=0, how='any', subset=['review_scores_rating'], inplace=True)

# %%
def prices_to_numbers(price_string):
    '''
    Converts USD prices from string to numeric format
    
    Args:
        price_string (string): USD price in string format (e.g., '$123,456.00')
    
    Returns:
        price_numeric (float): USD price in numeric format (e.g., 123456.00)
    '''
    
    price_numeric = float(str(price_string).replace(',', '').split('$')[-1])
    return price_numeric

# %%
listings_new['price'] = listings_new['price'].apply(prices_to_numbers)

# %%
listings_new['price'].value_counts()
# Out:
# 150.0    151
# 99.0     110
# 175.0     95
# 100.0     91
# 125.0     90
# 50.0      89
# 75.0      84
# 200.0     81
# 250.0     63
# 65.0      63
# 199.0     61
# 60.0      53
# 70.0      50
# 149.0     50
# 80.0      49
# 229.0     45
# 120.0     44
# 90.0      43
# 95.0      43
# 195.0     43
# 85.0      42
# 40.0      42
# 45.0      41
# 55.0      40
# 180.0     40
# 160.0     39
# 49.0      39
# 225.0     37
# 185.0     35
# 190.0     35
#         ...
# 436.0      1
# 251.0      1
# 206.0      1
# 244.0      1
# 15.0       1
# 296.0      1
# 204.0      1
# 152.0      1
# 392.0      1
# 20.0       1
# 356.0      1
# 256.0      1
# 136.0      1
# 19.0       1
# 456.0      1
# 17.0       1
# 304.0      1
# 294.0      1
# 793.0      1
# 515.0      1
# 589.0      1
# 451.0      1
# 271.0      1
# 328.0      1
# 236.0      1
# 388.0      1
# 212.0      1
# 353.0      1
# 247.0      1
# 829.0      1
# Name: price, Length: 362, dtype: int64

# %%
listings_new['security_deposit'].isnull().sum()
listings_new['security_deposit'].fillna(0, inplace=True)
listings_new['security_deposit'] = listings_new['security_deposit'].apply(prices_to_numbers)
listings_new['security_deposit'].value_counts()
# Out:
# 0.0       2085
# 100.0      386
# 400.0      373
# 500.0      267
# 200.0      228
# 300.0      185
# 150.0      141
# 250.0      130
# 1000.0      56
# 350.0       35
# 450.0       11
# 125.0        9
# 600.0        9
# 120.0        8
# 750.0        6
# 2000.0       5
# 3000.0       4
# 1500.0       4
# 700.0        4
# 180.0        3
# 299.0        3
# 550.0        3
# 1200.0       3
# 800.0        2
# 375.0        2
# 399.0        2
# 275.0        2
# 650.0        2
# 115.0        2
# 227.0        1
# 259.0        1
# 5000.0       1
# 160.0        1
# 4000.0       1
# 240.0        1
# 95.0         1
# 699.0        1
# 425.0        1
# 499.0        1
# 799.0        1
# 295.0        1
# 2500.0       1
# 199.0        1
# 249.0        1
# 475.0        1
# 175.0        1
# 353.0        1
# 119.0        1
# 105.0        1
# 999.0        1
# Name: security_deposit, dtype: int64

# %%
listings_new['cleaning_fee'].isnull().sum()
listings_new['cleaning_fee'].fillna(0, inplace=True)
listings_new['cleaning_fee'] = listings_new['cleaning_fee'].apply(prices_to_numbers)

# %%
listings_new['extra_people'] = listings_new['extra_people'].apply(prices_to_numbers)
listings_new['extra_people'].value_counts()
# Out:
# 0.0      1805
# 5.0       369
# 25.0      362
# 20.0      292
# 10.0      248
# 15.0      223
# 30.0      188
# 50.0      167
# 35.0       85
# 40.0       76
# 100.0      32
# 45.0       14
# 75.0       13
# 12.0       13
# 8.0        12
# 19.0       11
# 60.0        6
# 18.0        6
# 300.0       6
# 65.0        6
# 11.0        6
# 13.0        4
# 49.0        4
# 80.0        4
# 22.0        4
# 29.0        3
# 9.0         3
# 17.0        3
# 200.0       3
# 39.0        3
# 28.0        2
# 85.0        2
# 70.0        2
# 150.0       2
# 7.0         2
# 6.0         2
# 120.0       1
# 16.0        1
# 89.0        1
# 111.0       1
# 99.0        1
# 38.0        1
# 59.0        1
# 34.0        1
# Name: extra_people, dtype: int64

# %%
listings_new['has_availability'].value_counts()
# Out:
# t    3991
# Name: has_availability, dtype: int64

# %%
listings_new['number_of_reviews'].value_counts()
# Out:
# 1.0      304
# 2.0      202
# 3.0      175
# 4.0      137
# 5.0      122
# 6.0      117
# 7.0       93
# 10.0      90
# 8.0       87
# 9.0       77
# 13.0      68
# 11.0      65
# 17.0      62
# 14.0      57
# 18.0      57
# 15.0      55
# 12.0      51
# 23.0      48
# 21.0      44
# 22.0      44
# 20.0      42
# 28.0      39
# 39.0      39
# 19.0      39
# 30.0      38
# 25.0      37
# 16.0      36
# 32.0      35
# 29.0      35
# 31.0      34
#         ...
# 346.0      1
# 485.0      1
# 354.0      1
# 367.0      1
# 371.0      1
# 626.0      1
# 200.0      1
# 240.0      1
# 0.0        1
# 217.0      1
# 507.0      1
# 265.0      1
# 332.0      1
# 306.0      1
# 458.0      1
# 413.0      1
# 489.0      1
# 431.0      1
# 477.0      1
# 166.0      1
# 206.0      1
# 335.0      1
# 348.0      1
# 386.0      1
# 444.0      1
# 213.0      1
# 398.0      1
# 283.0      1
# 513.0      1
# 295.0      1
# Name: number_of_reviews, Length: 298, dtype: int64

# %%
listings_new['number_of_reviews_ltm'].value_counts()
# Out:
# 1.0      367
# 2.0      230
# 0.0      227
# 3.0      178
# 4.0      142
# 5.0      125
# 6.0      122
# 7.0      114
# 8.0      106
# 10.0      98
# 12.0      84
# 13.0      83
# 11.0      79
# 14.0      79
# 9.0       78
# 15.0      63
# 16.0      59
# 17.0      58
# 19.0      54
# 18.0      48
# 23.0      47
# 34.0      47
# 20.0      44
# 22.0      43
# 30.0      42
# 29.0      42
# 32.0      41
# 25.0      41
# 27.0      41
# 39.0      40
#         ...
# 101.0      2
# 120.0      2
# 107.0      2
# 100.0      2
# 131.0      2
# 116.0      2
# 93.0       2
# 114.0      2
# 117.0      2
# 109.0      1
# 128.0      1
# 138.0      1
# 150.0      1
# 80.0       1
# 108.0      1
# 137.0      1
# 141.0      1
# 143.0      1
# 99.0       1
# 149.0      1
# 94.0       1
# 156.0      1
# 105.0      1
# 102.0      1
# 119.0      1
# 113.0      1
# 145.0      1
# 134.0      1
# 104.0      1
# 133.0      1
# Name: number_of_reviews_ltm, Length: 135, dtype: int64

# %%
for index,row in listings_new.iterrows():
    if math.isnan(row['review_scores_accuracy']):
        row['review_scores_accuracy'] = row['review_scores_rating']/10
    if math.isnan(row['review_scores_cleanliness']):
        row['review_scores_cleanliness'] = row['review_scores_rating']/10
    if math.isnan(row['review_scores_checkin']):
        row['review_scores_checkin'] = row['review_scores_rating']/10
    if math.isnan(row['review_scores_communication']):
        row['review_scores_communication'] = row['review_scores_rating']/10
    if math.isnan(row['review_scores_location']):
        row['review_scores_location'] = row['review_scores_rating']/10
    if math.isnan(row['review_scores_value']):
        row['review_scores_value'] = row['review_scores_rating']/10

# %%
listings_new.dropna(axis=0, how='any', subset=['review_scores_accuracy','review_scores_cleanliness','review_scores_checkin','review_scores_communication','review_scores_location','review_scores_value'], inplace=True)

# %%
listings_new['instant_bookable'].value_counts()
# Out:
# t    2163
# f    1824
# Name: instant_bookable, dtype: int64

# %%
listings_new['cancellation_policy'].value_counts()
# Out:
# strict_14_with_grace_period    2234
# moderate                       1030
# flexible                        592
# super_strict_30                  73
# strict                           50
# super_strict_60                   8
# Name: cancellation_policy, dtype: int64

# %%
boolean_cols = ['host_is_superhost',
               'host_identity_verified',
               'is_location_exact',
               'instant_bookable',
               'require_guest_profile_picture',
               'require_guest_phone_verification']

# %%
def booleans_to_numbers(s):
    '''
    Converts "first letter boolean" strings to integers
    
    Args:
        bool_string (string): 't', 'f' or other
    
    Returns:
        bool_number (int): 1, 0 or None
    '''
    
    if(s == 'f'):
        return 0
    elif (s == 't'):
        return 1
    return None

# %%
for col in boolean_cols:
    listings_new[col] = listings_new[col].apply(booleans_to_numbers)

# %%
listings_new['reviews_per_month'].fillna(0, inplace=True)

# %% [markdown]
# ## Model Building

# %% [markdown]
# selecting the features for building the model

# %%
required_cols = ['host_response_time','host_response_rate','host_is_superhost','host_verification_level','neighbourhood_cleansed',
               'host_identity_verified',
               'is_location_exact',
               'instant_bookable','property_type','room_type','bed_type','Wifi', 'Heating', 'Essentials', 'Smoke detector', 'Kitchen',
       'Carbon monoxide detector', 'Hangers', 'Air conditioning', 'Shampoo',
       'Hair dryer','price','security_deposit','cleaning_fee','extra_people','number_of_reviews','review_scores_rating','review_scores_cleanliness','review_scores_checkin','review_scores_communication','review_scores_location','cancellation_policy','reviews_per_month']

# %%
listings_final = listings_new[required_cols]
listings_final
# Out:
#       host_response_time  host_response_rate  host_is_superhost  \
# 0                    2.0               100.0                  1
# 1                    1.0               100.0                  1
# 2                    1.0               100.0                  1
# 4                    3.0                93.0                  0
# 5                    3.0                93.0                  0
# 6                    4.0                33.0                  0
# 7                    4.0                33.0                  0
# 8                    4.0                33.0                  0
# 10                   4.0                33.0                  0
# 12                   4.0                33.0                  0
# 13                   4.0                33.0                  0
# 14                   4.0                33.0                  0
# 15                   3.0                93.0                  0
# 16                   2.0                90.0                  0
# 19                   4.0                33.0                  0
# 20                   4.0                33.0                  0
# 21                   1.0               100.0                  0
# 22                   4.0                33.0                  0
# 23                   4.0                33.0                  0
# 24                   1.0               100.0                  0
# 25                   4.0                33.0                  0
# 27                   2.0               100.0                  1
# 28                   4.0                33.0                  0
# 29                   4.0                33.0                  0
# 30                   4.0                33.0                  0
# 31                   1.0               100.0                  0
# 33                   4.0                33.0                  0
# 34                   4.0                33.0                  0
# 35                   3.0               100.0                  0
# 37                   1.0               100.0                  0
# ...                  ...                 ...                ...
# 5962                 1.0               100.0                  1
# 5963                 1.0               100.0                  0
# 5964                 2.0                92.0                  0
# 5965                 1.0               100.0                  1
# 5967                 1.0               100.0                  0
# 5970                 1.0                96.0                  0
# 5974                 3.0               100.0                  0
# 5979                 1.0               100.0                  0
# 5981                 3.0               100.0                  0
# 5984                 1.0               100.0                  0
# 5997                 1.0                94.0                  0
# 6003                 1.0                93.0                  0
# 6011                 1.0                98.0                  0
# 6012                 1.0               100.0                  0
# 6015                 1.0               100.0                  0
# 6016                 1.0               100.0                  0
# 6021                 1.0                98.0                  0
# 6022                 1.0               100.0                  1
# 6029                 1.0               100.0                  0
# 6030                 1.0                98.0                  0
# 6033                 1.0               100.0                  0
# 6036                 1.0               100.0                  0
# 6041                 3.0               100.0                  0
# 6042                 1.0               100.0                  0
# 6045                 1.0               100.0                  0
# 6056                 2.0               100.0                  0
# 6064                 1.0                84.0                  0
# 6087                 1.0               100.0                  0
# 6095                 1.0               100.0                  0
# 6102                 1.0                91.0                  0
#
#       host_verification_level neighbourhood_cleansed  host_identity_verified  \
# 0                         3.0            East Boston                       0
# 1                         4.0                Roxbury                       1
# 2                         4.0                Roxbury                       1
# 4                         8.0               Downtown                       0
# 5                         8.0               Downtown                       0
# 6                         6.0              South End                       1
# 7                         6.0               Back Bay                       1
# 8                         6.0               Downtown                       1
# 10                        6.0               Back Bay                       1
# 12                        6.0               Back Bay                       1
# 13                        6.0               Back Bay                       1
# 14                        6.0              South End                       1
# 15                        8.0               Downtown                       0
# 16                        8.0               Back Bay                       0
# 19                        6.0               Back Bay                       1
# 20                        6.0               Back Bay                       1
# 21                        6.0             Dorchester                       1
# 22                        6.0               Downtown                       1
# 23                        6.0              South End                       1
# 24                        5.0              South End                       1
# 25                        6.0               Back Bay                       1
# 27                        4.0              North End                       0
# 28                        6.0                 Fenway                       1
# 29                        6.0               West End                       1
# 30                        6.0              South End                       1
# 31                        6.0             Dorchester                       1
# 33                        6.0               Back Bay                       1
# 34                        6.0               Back Bay                       1
# 35                        4.0            Charlestown                       1
# 37                        6.0             Dorchester                       1
# ...                       ...                    ...                     ...
# 5962                      4.0               Brighton                       1
# 5963                      7.0                 Fenway                       0
# 5964                      2.0              South End                       0
# 5965                      9.0               Downtown                       0
# 5967                      1.0               Back Bay                       0
# 5970                      6.0                Allston                       0
# 5974                      6.0            East Boston                       1
# 5979                      2.0               Downtown                       0
# 5981                      4.0               Back Bay                       0
# 5984                      5.0            East Boston                       1
# 5997                      4.0          Jamaica Plain                       1
# 6003                      7.0                 Fenway                       1
# 6011                      8.0          Jamaica Plain                       0
# 6012                      2.0              Hyde Park                       0
# 6015                      7.0                Allston                       0
# 6016                      2.0           South Boston                       0
# 6021                      6.0                 Fenway                       0
# 6022                      2.0               Back Bay                       0
# 6029                      8.0                Allston                       0
# 6030                      5.0           South Boston                       0
# 6033                      8.0                Allston                       0
# 6036                      6.0          Jamaica Plain                       0
# 6041                      2.0          Jamaica Plain                       0
# 6042                      1.0            East Boston                       0
# 6045                      4.0               Brighton                       0
# 6056                      6.0               Brighton                       0
# 6064                      2.0              South End                       0
# 6087                      3.0            East Boston                       0
# 6095                      5.0            East Boston                       1
# 6102                      6.0             Dorchester                       0
#
#       is_location_exact  instant_bookable       property_type  \
# 0                     1                 0           Apartment
# 1                     1                 1         Guest suite
# 2                     1                 1         Condominium
# 4                     1                 0           Apartment
# 5                     1                 0           Apartment
# 6                     1                 0           Apartment
# 7                     1                 0  Serviced apartment
# 8                     1                 0  Serviced apartment
# 10                    1                 0           Apartment
# 12                    1                 0  Serviced apartment
# 13                    1                 0  Serviced apartment
# 14                    1                 0  Serviced apartment
# 15                    1                 0           Apartment
# 16                    0                 0           Apartment
# 19                    1                 0  Serviced apartment
# 20                    1                 0           Apartment
# 21                    1                 1  Serviced apartment
# 22                    1                 0           Apartment
# 23                    1                 0  Serviced apartment
# 24                    1                 1   Bed and breakfast
# 25                    1                 0           Apartment
# 27                    1                 0               Other
# 28                    1                 0           Apartment
# 29                    1                 0           Apartment
# 30                    1                 0  Serviced apartment
# 31                    1                 1               House
# 33                    1                 0           Apartment
# 34                    1                 0  Serviced apartment
# 35                    1                 1           Apartment
# 37                    1                 1               House
# ...                 ...               ...                 ...
# 5962                  1                 1         Condominium
# 5963                  1                 1           Apartment
# 5964                  1                 0           Apartment
# 5965                  1                 1           Apartment
# 5967                  1                 1           Apartment
# 5970                  1                 1           Apartment
# 5974                  0                 0           Apartment
# 5979                  0                 1           Apartment
# 5981                  1                 1         Condominium
# 5984                  1                 1         Condominium
# 5997                  1                 1           Apartment
# 6003                  1                 0           Apartment
# 6011                  1                 1           Apartment
# 6012                  1                 1           Apartment
# 6015                  1                 0           Apartment
# 6016                  1                 1         Condominium
# 6021                  1                 1           Apartment
# 6022                  1                 1      Boutique hotel
# 6029                  1                 1               House
# 6030                  0                 1         Guest suite
# 6033                  1                 1               House
# 6036                  1                 1   Bed and breakfast
# 6041                  1                 0         Condominium
# 6042                  1                 1         Condominium
# 6045                  1                 0         Condominium
# 6056                  0                 0         Condominium
# 6064                  0                 1      Boutique hotel
# 6087                  0                 1           Apartment
# 6095                  0                 1         Condominium
# 6102                  1                 1           Apartment
#
#             room_type  ... cleaning_fee extra_people number_of_reviews  \
# 0     Entire home/apt  ...         75.0          0.0              14.0
# 1     Entire home/apt  ...         40.0          0.0              80.0
# 2     Entire home/apt  ...         70.0          8.0              85.0
# 4     Entire home/apt  ...        250.0          0.0              22.0
# 5     Entire home/apt  ...        250.0          0.0              24.0
# 6     Entire home/apt  ...         75.0          0.0               9.0
# 7     Entire home/apt  ...          0.0          0.0              23.0
# 8     Entire home/apt  ...        150.0          0.0               8.0
# 10    Entire home/apt  ...          0.0          0.0              25.0
# 12    Entire home/apt  ...          0.0          0.0               3.0
# 13    Entire home/apt  ...          0.0          0.0              22.0
# 14    Entire home/apt  ...          0.0          0.0               8.0
# 15    Entire home/apt  ...        250.0          0.0              27.0
# 16    Entire home/apt  ...        100.0          0.0               7.0
# 19    Entire home/apt  ...          0.0          0.0              63.0
# 20    Entire home/apt  ...          0.0          0.0              20.0
# 21    Entire home/apt  ...        120.0         13.0              43.0
# 22    Entire home/apt  ...        200.0          0.0              21.0
# 23    Entire home/apt  ...          0.0          0.0               4.0
# 24       Private room  ...         21.0         15.0             293.0
# 25    Entire home/apt  ...        150.0          0.0               5.0
# 27    Entire home/apt  ...          0.0         60.0              82.0
# 28    Entire home/apt  ...        150.0          0.0               9.0
# 29    Entire home/apt  ...        200.0          0.0               4.0
# 30    Entire home/apt  ...          0.0          0.0               4.0
# 31       Private room  ...         25.0         15.0             234.0
# 33    Entire home/apt  ...          0.0          0.0              21.0
# 34    Entire home/apt  ...          0.0          0.0              33.0
# 35    Entire home/apt  ...         25.0          0.0              93.0
# 37       Private room  ...         25.0         15.0             412.0
# ...               ...  ...          ...          ...               ...
# 5962     Private room  ...         15.0          0.0               3.0
# 5963  Entire home/apt  ...         75.0          0.0               2.0
# 5964  Entire home/apt  ...         50.0         10.0               3.0
# 5965  Entire home/apt  ...          0.0          0.0               1.0
# 5967  Entire home/apt  ...         55.0          0.0               1.0
# 5970  Entire home/apt  ...         40.0         25.0               4.0
# 5974  Entire home/apt  ...         19.0          0.0               1.0
# 5979  Entire home/apt  ...         99.0          0.0               4.0
# 5981  Entire home/apt  ...         50.0          0.0               1.0
# 5984  Entire home/apt  ...        139.0         20.0               4.0
# 5997  Entire home/apt  ...        165.0         13.0               1.0
# 6003  Entire home/apt  ...          0.0          0.0               2.0
# 6011  Entire home/apt  ...         79.0          0.0               1.0
# 6012  Entire home/apt  ...          0.0          0.0               1.0
# 6015     Private room  ...         58.0         50.0               5.0
# 6016  Entire home/apt  ...         50.0          0.0               4.0
# 6021  Entire home/apt  ...          0.0          0.0               5.0
# 6022     Private room  ...          0.0          0.0               2.0
# 6029     Private room  ...         25.0         20.0               1.0
# 6030  Entire home/apt  ...         49.0         25.0               3.0
# 6033     Private room  ...         25.0         20.0               1.0
# 6036     Private room  ...         25.0         25.0               1.0
# 6041     Private room  ...          6.0          5.0               2.0
# 6042     Private room  ...          5.0         10.0               2.0
# 6045     Private room  ...         30.0          8.0               2.0
# 6056     Private room  ...         15.0         10.0               2.0
# 6064     Private room  ...          0.0          0.0               1.0
# 6087  Entire home/apt  ...          0.0          0.0               2.0
# 6095  Entire home/apt  ...         39.0          0.0               1.0
# 6102  Entire home/apt  ...          0.0          0.0               3.0
#
#      review_scores_rating review_scores_cleanliness review_scores_checkin  \
# 0                    99.0                      10.0                  10.0
# 1                    95.0                      10.0                  10.0
# 2                    97.0                      10.0                  10.0
# 4                    92.0                       9.0                  10.0
# 5                    93.0                       9.0                  10.0
# 6                    89.0                      10.0                  10.0
# 7                    79.0                       9.0                  10.0
# 8                    96.0                      10.0                   9.0
# 10                   88.0                      10.0                  10.0
# 12                   87.0                      10.0                  10.0
# 13                   85.0                       9.0                  10.0
# 14                   80.0                       8.0                  10.0
# 15                   95.0                       9.0                  10.0
# 16                   86.0                       9.0                   9.0
# 19                   87.0                       9.0                  10.0
# 20                   78.0                       9.0                  10.0
# 21                   84.0                       9.0                   9.0
# 22                   94.0                       9.0                   9.0
# 23                   90.0                       9.0                  10.0
# 24                   89.0                       9.0                   9.0
# 25                   87.0                       9.0                   7.0
# 27                   96.0                      10.0                  10.0
# 28                   88.0                      10.0                   9.0
# 29                   95.0                       9.0                   8.0
# 30                   70.0                       8.0                   8.0
# 31                   88.0                       9.0                   9.0
# 33                   81.0                       8.0                   9.0
# 34                   88.0                       9.0                  10.0
# 35                   99.0                      10.0                  10.0
# 37                   88.0                       9.0                  10.0
# ...                   ...                       ...                   ...
# 5962                100.0                      10.0                  10.0
# 5963                 90.0                      10.0                  10.0
# 5964                100.0                      10.0                  10.0
# 5965                100.0                      10.0                  10.0
# 5967                 80.0                      10.0                   6.0
# 5970                100.0                      10.0                  10.0
# 5974                100.0                       8.0                  10.0
# 5979                100.0                      10.0                  10.0
# 5981                100.0                      10.0                  10.0
# 5984                100.0                      10.0                  10.0
# 5997                100.0                      10.0                  10.0
# 6003                 90.0                      10.0                  10.0
# 6011                100.0                      10.0                  10.0
# 6012                 20.0                       2.0                   2.0
# 6015                100.0                      10.0                  10.0
# 6016                 95.0                      10.0                  10.0
# 6021                100.0                      10.0                  10.0
# 6022                100.0                      10.0                  10.0
# 6029                100.0                      10.0                  10.0
# 6030                100.0                      10.0                  10.0
# 6033                100.0                      10.0                  10.0
# 6036                100.0                      10.0                  10.0
# 6041                100.0                      10.0                  10.0
# 6042                 80.0                      10.0                  10.0
# 6045                100.0                      10.0                  10.0
# 6056                100.0                       9.0                   8.0
# 6064                100.0                      10.0                  10.0
# 6087                 70.0                       9.0                  10.0
# 6095                 20.0                       2.0                   2.0
# 6102                 70.0                       8.0                   7.0
#
#      review_scores_communication review_scores_location  \
# 0                           10.0                   10.0
# 1                           10.0                    9.0
# 2                           10.0                    9.0
# 4                           10.0                   10.0
# 5                           10.0                   10.0
# 6                            9.0                   10.0
# 7                            9.0                   10.0
# 8                            9.0                    9.0
# 10                          10.0                   10.0
# 12                          10.0                   10.0
# 13                           9.0                   10.0
# 14                           9.0                   10.0
# 15                          10.0                   10.0
# 16                           7.0                   10.0
# 19                          10.0                   10.0
# 20                           9.0                   10.0
# 21                           9.0                    9.0
# 22                           9.0                   10.0
# 23                          10.0                    9.0
# 24                           9.0                   10.0
# 25                           7.0                    9.0
# 27                          10.0                   10.0
# 28                           9.0                    9.0
# 29                           8.0                    8.0
# 30                          10.0                    9.0
# 31                           9.0                    8.0
# 33                           9.0                   10.0
# 34                           9.0                   10.0
# 35                          10.0                   10.0
# 37                          10.0                    9.0
# ...                          ...                    ...
# 5962                        10.0                    9.0
# 5963                        10.0                    8.0
# 5964                         9.0                   10.0
# 5965                        10.0                   10.0
# 5967                         4.0                   10.0
# 5970                        10.0                   10.0
# 5974                        10.0                   10.0
# 5979                        10.0                   10.0
# 5981                        10.0                   10.0
# 5984                        10.0                   10.0
# 5997                        10.0                   10.0
# 6003                        10.0                   10.0
# 6011                        10.0                   10.0
# 6012                         2.0                    2.0
# 6015                        10.0                   10.0
# 6016                        10.0                   10.0
# 6021                         9.0                   10.0
# 6022                        10.0                   10.0
# 6029                        10.0                   10.0
# 6030                        10.0                   10.0
# 6033                        10.0                   10.0
# 6036                        10.0                   10.0
# 6041                        10.0                   10.0
# 6042                        10.0                   10.0
# 6045                        10.0                    9.0
# 6056                         8.0                    9.0
# 6064                        10.0                   10.0
# 6087                        10.0                   10.0
# 6095                        10.0                    6.0
# 6102                        10.0                   10.0
#
#               cancellation_policy reviews_per_month
# 0                 super_strict_30              0.32
# 1     strict_14_with_grace_period              0.66
# 2     strict_14_with_grace_period              0.73
# 4     strict_14_with_grace_period              0.40
# 5     strict_14_with_grace_period              0.21
# 6                 super_strict_30              0.10
# 7                 super_strict_30              0.25
# 8                 super_strict_30              0.08
# 10                super_strict_30              0.28
# 12                super_strict_30              0.03
# 13                super_strict_30              0.20
# 14                super_strict_30              0.10
# 15    strict_14_with_grace_period              0.24
# 16    strict_14_with_grace_period              0.19
# 19                super_strict_30              0.59
# 20                super_strict_30              0.20
# 21    strict_14_with_grace_period              0.40
# 22                super_strict_30              0.22
# 23                super_strict_30              0.04
# 24                       moderate              3.20
# 25                super_strict_30              0.05
# 27    strict_14_with_grace_period              0.81
# 28                super_strict_30              0.09
# 29                super_strict_30              0.04
# 30                super_strict_30              0.04
# 31                       flexible              2.20
# 33                super_strict_30              0.24
# 34                super_strict_30              0.41
# 35    strict_14_with_grace_period              0.88
# 37    strict_14_with_grace_period              3.91
# ...                           ...               ...
# 5962  strict_14_with_grace_period              3.00
# 5963                     flexible              2.00
# 5964                     moderate              2.65
# 5965                     flexible              1.00
# 5967  strict_14_with_grace_period              1.00
# 5970                     moderate              4.00
# 5974  strict_14_with_grace_period              1.00
# 5979                     moderate              4.00
# 5981                     flexible              1.00
# 5984  strict_14_with_grace_period              4.00
# 5997  strict_14_with_grace_period              1.00
# 6003                     flexible              2.00
# 6011  strict_14_with_grace_period              1.00
# 6012                     flexible              1.00
# 6015                     flexible              5.00
# 6016  strict_14_with_grace_period              4.00
# 6021                     flexible              5.00
# 6022                     moderate              2.00
# 6029                     flexible              1.00
# 6030                     moderate              3.00
# 6033                     flexible              1.00
# 6036                     moderate              1.00
# 6041                     flexible              2.00
# 6042                     flexible              2.00
# 6045                     flexible              2.00
# 6056                     flexible              2.00
# 6064                     moderate              1.00
# 6087                     moderate              2.00
# 6095                     flexible              1.00
# 6102                     flexible              3.00
#
# [3987 rows x 33 columns]

# %%
listings_final.to_csv('../data/cleanListings.csv')

# %%
listings_dum = pd.get_dummies(listings_final)

# %% [markdown]
# checking nulls before passing the dependant variables to the randrom forest regressor

# %%
listings_dum.isnull().sum()
# Out:
# host_response_time                                 0
# host_response_rate                                 0
# host_is_superhost                                  0
# host_verification_level                            0
# host_identity_verified                             0
# is_location_exact                                  0
# instant_bookable                                   0
# price                                              0
# security_deposit                                   0
# cleaning_fee                                       0
# extra_people                                       0
# number_of_reviews                                  0
# review_scores_rating                               0
# review_scores_cleanliness                          0
# review_scores_checkin                              0
# review_scores_communication                        0
# review_scores_location                             0
# reviews_per_month                                  0
# neighbourhood_cleansed_Allston                     0
# neighbourhood_cleansed_Back Bay                    0
# neighbourhood_cleansed_Bay Village                 0
# neighbourhood_cleansed_Beacon Hill                 0
# neighbourhood_cleansed_Brighton                    0
# neighbourhood_cleansed_Charlestown                 0
# neighbourhood_cleansed_Chinatown                   0
# neighbourhood_cleansed_Dorchester                  0
# neighbourhood_cleansed_Downtown                    0
# neighbourhood_cleansed_East Boston                 0
# neighbourhood_cleansed_Fenway                      0
# neighbourhood_cleansed_Hyde Park                   0
#                                                   ..
# bed_type_Couch                                     0
# bed_type_Futon                                     0
# bed_type_Pull-out Sofa                             0
# bed_type_Real Bed                                  0
# Wifi_False                                         0
# Wifi_True                                          0
# Heating_False                                      0
# Heating_True                                       0
# Essentials_False                                   0
# Essentials_True                                    0
# Smoke detector_False                               0
# Smoke detector_True                                0
# Kitchen_False                                      0
# Kitchen_True                                       0
# Carbon monoxide detector_False                     0
# Carbon monoxide detector_True                      0
# Hangers_False                                      0
# Hangers_True                                       0
# Air conditioning_False                             0
# Air conditioning_True                              0
# Shampoo_False                                      0
# Shampoo_True                                       0
# Hair dryer_False                                   0
# Hair dryer_True                                    0
# cancellation_policy_flexible                       0
# cancellation_policy_moderate                       0
# cancellation_policy_strict                         0
# cancellation_policy_strict_14_with_grace_period    0
# cancellation_policy_super_strict_30                0
# cancellation_policy_super_strict_60                0
# Length: 87, dtype: int64

# %%
labels = np.array(listings_dum['review_scores_rating'])

# Remove the labels from the features, so we have one table for independent variables 
# (axis 1 refers to columns)
listings_dum = listings_dum.drop('review_scores_rating', axis = 1)

# Saving feature names for later use
feature_list = list(listings_dum.columns)

# Convert to numpy array
listings_dum = np.array(listings_dum)

# %%
# Using Skicit-learn to split data into training and testing sets
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
train_features, test_features, train_labels, test_labels = train_test_split(listings_dum, labels, test_size = 0.25,
                                                                           random_state = 42)

# %%
print('Training Features Shape:', train_features.shape)
print('Training Labels Shape:', train_labels.shape)
print('Testing Features Shape:', test_features.shape)
print('Testing Labels Shape:', test_labels.shape)
# Out:
# Training Features Shape: (2990, 86)
# Training Labels Shape: (2990,)
# Testing Features Shape: (997, 86)
# Testing Labels Shape: (997,)

# %%
from sklearn.ensemble import RandomForestRegressor

# Instantiate model 
rf = RandomForestRegressor(n_estimators= 1000, random_state=42)

# Train the model on training data
rf.fit(train_features, train_labels);

# %%
rf.get_params
# Out:
# <bound method BaseEstimator.get_params of RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=None,
#            oob_score=False, random_state=42, verbose=0, warm_start=False)>

# %%
# Use the forest's predict method on the test data
predictions = rf.predict(test_features)

# Calculate the absolute errors
errors = abs(predictions - test_labels)

# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2))
# Out:
# Mean Absolute Error: 2.84

# %%
# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / test_labels)

# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 96.72 %.

# %% [markdown]
# Whoops!! there a chance of overfitting as the accuracy is ~ 97%
#
# But also the values of review score rating in our dataset are in mostly in the range of 90 - 100. so getting a Mean Absolute error of 2.84 is considerable

# %%
# Get numerical feature importances
importances = list(rf.feature_importances_)

# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]

# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)

# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: review_scores_communication Importance: 0.32
# Variable: review_scores_cleanliness Importance: 0.31
# Variable: number_of_reviews    Importance: 0.04
# Variable: reviews_per_month    Importance: 0.04
# Variable: price                Importance: 0.03
# Variable: review_scores_checkin Importance: 0.03
# Variable: review_scores_location Importance: 0.03
# Variable: host_response_rate   Importance: 0.02
# Variable: cleaning_fee         Importance: 0.02
# Variable: neighbourhood_cleansed_Downtown Importance: 0.02
# Variable: host_response_time   Importance: 0.01
# Variable: host_is_superhost    Importance: 0.01
# Variable: host_verification_level Importance: 0.01
# Variable: security_deposit     Importance: 0.01
# Variable: extra_people         Importance: 0.01
# Variable: neighbourhood_cleansed_West Roxbury Importance: 0.01
# Variable: host_identity_verified Importance: 0.0
# Variable: is_location_exact    Importance: 0.0
# Variable: instant_bookable     Importance: 0.0
# Variable: neighbourhood_cleansed_Allston Importance: 0.0
# Variable: neighbourhood_cleansed_Back Bay Importance: 0.0
# Variable: neighbourhood_cleansed_Bay Village Importance: 0.0
# Variable: neighbourhood_cleansed_Beacon Hill Importance: 0.0
# Variable: neighbourhood_cleansed_Brighton Importance: 0.0
# Variable: neighbourhood_cleansed_Charlestown Importance: 0.0
# Variable: neighbourhood_cleansed_Chinatown Importance: 0.0
# Variable: neighbourhood_cleansed_Dorchester Importance: 0.0
# Variable: neighbourhood_cleansed_East Boston Importance: 0.0
# Variable: neighbourhood_cleansed_Fenway Importance: 0.0
# Variable: neighbourhood_cleansed_Hyde Park Importance: 0.0
# Variable: neighbourhood_cleansed_Jamaica Plain Importance: 0.0
# Variable: neighbourhood_cleansed_Leather District Importance: 0.0
# Variable: neighbourhood_cleansed_Longwood Medical Area Importance: 0.0
# Variable: neighbourhood_cleansed_Mattapan Importance: 0.0
# Variable: neighbourhood_cleansed_Mission Hill Importance: 0.0
# Variable: neighbourhood_cleansed_North End Importance: 0.0
# Variable: neighbourhood_cleansed_Roslindale Importance: 0.0
# Variable: neighbourhood_cleansed_Roxbury Importance: 0.0
# Variable: neighbourhood_cleansed_South Boston Importance: 0.0
# Variable: neighbourhood_cleansed_South Boston Waterfront Importance: 0.0
# Variable: neighbourhood_cleansed_South End Importance: 0.0
# Variable: neighbourhood_cleansed_West End Importance: 0.0
# Variable: property_type_Apartment Importance: 0.0
# Variable: property_type_Bed and breakfast Importance: 0.0
# Variable: property_type_Boutique hotel Importance: 0.0
# Variable: property_type_Condominium Importance: 0.0
# Variable: property_type_Guest suite Importance: 0.0
# Variable: property_type_House  Importance: 0.0
# Variable: property_type_Loft   Importance: 0.0
# Variable: property_type_Other  Importance: 0.0
# Variable: property_type_Serviced apartment Importance: 0.0
# Variable: property_type_Townhouse Importance: 0.0
# Variable: room_type_Entire home/apt Importance: 0.0
# Variable: room_type_Private room Importance: 0.0
# Variable: room_type_Shared room Importance: 0.0
# Variable: bed_type_Airbed      Importance: 0.0
# Variable: bed_type_Couch       Importance: 0.0
# Variable: bed_type_Futon       Importance: 0.0
# Variable: bed_type_Pull-out Sofa Importance: 0.0
# Variable: bed_type_Real Bed    Importance: 0.0
# Variable: Wifi_False           Importance: 0.0
# Variable: Wifi_True            Importance: 0.0
# Variable: Heating_False        Importance: 0.0
# Variable: Heating_True         Importance: 0.0
# Variable: Essentials_False     Importance: 0.0
# Variable: Essentials_True      Importance: 0.0
# Variable: Smoke detector_False Importance: 0.0
# Variable: Smoke detector_True  Importance: 0.0
# Variable: Kitchen_False        Importance: 0.0
# Variable: Kitchen_True         Importance: 0.0
# Variable: Carbon monoxide detector_False Importance: 0.0
# Variable: Carbon monoxide detector_True Importance: 0.0
# Variable: Hangers_False        Importance: 0.0
# Variable: Hangers_True         Importance: 0.0
# Variable: Air conditioning_False Importance: 0.0
# Variable: Air conditioning_True Importance: 0.0
# Variable: Shampoo_False        Importance: 0.0
# Variable: Shampoo_True         Importance: 0.0
# Variable: Hair dryer_False     Importance: 0.0
# Variable: Hair dryer_True      Importance: 0.0
# Variable: cancellation_policy_flexible Importance: 0.0
# Variable: cancellation_policy_moderate Importance: 0.0
# Variable: cancellation_policy_strict Importance: 0.0
# Variable: cancellation_policy_strict_14_with_grace_period Importance: 0.0
# Variable: cancellation_policy_super_strict_30 Importance: 0.0
# Variable: cancellation_policy_super_strict_60 Importance: 0.0

# %% [markdown]
# Based on the given information about data `review_score_cleanliness` is the rating given for cleanliness that listing.`review_scores_communication` is tells about the interaction with the host.
#
# The variable importance of random forest also tells that the features review_score_cleanliness, review_scores_communication are important

# %% [markdown]
# Performing GridSearchCV for Hyperparamter tuning

# %%
gsc = GridSearchCV(
        estimator=RandomForestRegressor(),
        param_grid={
            'max_depth': range(3,10),
            'n_estimators': (10, 50, 100, 1000),
        },
        cv=5, scoring='neg_mean_squared_error', verbose=0, n_jobs=-1)
    
grid_result = gsc.fit(listings_dum, labels)

# %%
best_params = grid_result.best_params_
rfr = RandomForestRegressor(max_depth=best_params["max_depth"], n_estimators=best_params["n_estimators"],                          random_state=False, verbose=False)
# Perform 10-Fold CV 
scores = cross_val_score(rfr, listings_dum, labels, cv=10, scoring='neg_mean_squared_error')

# %%
best_params

# %%
rfr.fit(train_features,train_labels)

# %%
print(rfr.get_params)

# %%
predictions_cv = rfr.predict(test_features)

# %%
# Calculate the absolute errors
errors = abs(predictions_cv - test_labels)

# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2))

# %%
pd.DataFrame(grid_result.cv_results_)

# %%
predictions = cross_val_predict(rfr, listings_dum, labels, cv = 10)

# %%
len(predictions)

# %%
listings_final['neighbourhood_cleansed']
